# %%
import numpy as np

# %%
# Array declaration
arr = np.array([10,20,30,40])
print("Element at position 2: ",arr[2])
# Out:
# Element at position 2:  30

# %%
np.int64(50)
# Out:
# np.int64(50)

# %%
print(arr)
# Out:
# [10 20 30 40]

# %%
print(arr[1:3])
# Out:
# [20 30]

# %%
matrix = np.array([[1,2,3],[4,6,7],[6,8,9]])
print(matrix)
# Out:
# [[1 2 3]
#  [4 6 7]
#  [6 8 9]]

# %%
print(matrix[1,1])
# Out:
# 6

# %%
print(matrix[0:1,:])
# Out:
# [[1 2 3]]

# %%
arr1 = np.array([1,2,3])
scalar = 5
print(arr1+scalar)
# Out:
# [6 7 8]

# %%
arr1
# Out:
# array([6, 7, 8])

# %%
arr1 = arr1+scalar
arr1
# Out:
# array([6, 7, 8])

# %%
prices = np.array([100,200,300])
dis = np.array([5,10,15]) # %discounts
final_prices = prices * (1-dis/100)
print("Final prices: ",final_prices)
# Out:
# Final prices:  [ 95. 180. 255.]
