# %%
import pandas as pd
import numpy as np

# %%
data = [10,20,30]
s = pd.Series(data)
s

# %%
seriesWithIndex = pd.Series(data,index=['a','b','c'])
seriesWithIndex

# %%
print(seriesWithIndex['b'])

# %%
print(s[2])

# %%
data2 = {
    "Name" : ["Jamiya", "Begam", "Anish"],
    "Age" : [20,30,20],
    "Country" : ["USA","India","Canada"]
}

# %%
dataFrame = pd.DataFrame(data2)

# %%
dataFrame

# %%
dataFrame.shape

# %%
dataFrame.columns

# %%
dataFrame.index

# %%
dataFrame.head(2)

# %%
dataFrame.tail(1)

# %%
dataFrame.info()

# %%
dataFrame.dtypes

# %%
dataFrame.describe()

# %%
df = pd.read_csv(r"C:\Users\jamiy\Downloads\ecommerce_sales_data.csv")
df
# Out:
#        OrderID CustomerID    CustomerName    Age  Gender      City State  \
# 0     ORD00001   CUST0103      John Smith   22.0  Female   Chicago    PA
# 1     ORD00002   CUST0271   William Moore   18.0    Male   Chicago    OH
# 2     ORD00003   CUST0107   William Moore  120.0  Female  San Jose    AZ
# 3     ORD00004   CUST0072   Jessica White   29.0    Male    Dallas    NY
# 4     ORD00005   CUST0189   Lisa Anderson   53.0  Female   Houston    NY
# ...        ...        ...             ...    ...     ...       ...   ...
# 1010  ORD00807   CUST0203    Jennifer Lee   19.0    Male   Houston    FL
# 1011  ORD00324   CUST0153  Sarah Williams   65.0  Female   Chicago    AZ
# 1012  ORD00132   CUST0045    Tom Martinez   23.0  Female  New York    NY
# 1013  ORD00026   CUST0188    Chris Wilson   29.0    Male  New York    PA
# 1014  ORD00828   CUST0178    James Harris   46.0    Male  New York    CA
#
#            Category ProductName  Quantity  ...  Discount  ShippingCost  \
# ...

# %%
v = df.groupby('Category')['FinalPrice'].sum()
v
# Out:
# Category
# Beauty            86377.1160
# Books             71441.4495
# Clothing         115002.6655
# Electronics       82825.4235
# Food              85336.1810
# Home & Garden     79780.5510
# Sports            80901.6000
# Toys             102711.1525
# Name: FinalPrice, dtype: float64

# %%
df[df['ProductName']=='Lipstick']
# Out:
#       OrderID CustomerID    CustomerName    Age  Gender         City State  \
# 2    ORD00003   CUST0107   William Moore  120.0  Female     San Jose    AZ
# 10   ORD00011   CUST0100    James Harris   27.0    Male      Chicago    NY
# 14   ORD00015   CUST0258    Jennifer Lee   27.0    Male  San Antonio    OH
# 34   ORD00035   CUST0021      John Smith   54.0    Male      Phoenix    NY
# 44   ORD00045   CUST0035    Chris Wilson   67.0  Female  San Antonio    CA
# ..        ...        ...             ...    ...     ...          ...   ...
# 859  ORD00860   CUST0062  Sarah Williams   58.0    Male  Los Angeles    IL
# 878  ORD00879   CUST0104   William Moore   23.0    Male     San Jose    GA
# 948  ORD00949   CUST0267      Amy Taylor   37.0  Female    San Diego    CA
# 966  ORD00967   CUST0294   Jessica White   30.0  Female       Dallas    FL
# 967  ORD00968   CUST0210    Chris Wilson   60.0  Female      Houston    IL
#
# ...

# %%
agg_summary = df.groupby(['Category', 'ProductName','Discount']).agg({
    'FinalPrice': ['sum','mean'],
    'Quantity' : 'mean'
})
agg_summary
# Out:
#                               FinalPrice               Quantity
#                                      sum         mean      mean
# Category ProductName Discount
# Beauty   Basketball  5         1934.4235   644.807833  3.333333
#                      15         769.1925   769.192500  5.000000
#                      20        1437.7920  1437.792000  4.000000
#          Chocolate   0         4207.1300   841.426000  3.200000
#                      5          102.9540   102.954000  2.000000
# ...                                  ...          ...       ...
# Toys     T-Shirt     5         3124.1145  1041.371500  3.000000
#                      10        2202.6300   550.657500  3.000000
#                      15         356.5635   356.563500  1.000000
#                      20         193.4380   193.438000  1.000000
#                      25         986.9875   493.493750  4.500000
#
# [461 rows x 3 columns]

# %%
insight = df['Discount'].describe()
insight
# Out:
# count    1015.000000
# mean        6.359606
# std         7.051777
# min         0.000000
# 25%         0.000000
# 50%         5.000000
# 75%        10.000000
# max        25.000000
# Name: Discount, dtype: float64

# %%
print(df.columns) #print(df.columns.to_list)
# Out:
# Index(['OrderID', 'CustomerID', 'CustomerName', 'Age', 'Gender', 'City',
#        'State', 'Category', 'ProductName', 'Quantity', 'UnitPrice', 'Discount',
#        'ShippingCost', 'PaymentMethod', 'OrderDate', 'DeliveryDays', 'Rating',
#        'CustomerSatisfaction', 'TotalPrice', 'DiscountAmount', 'FinalPrice'],
#       dtype='object')

# %%
new_row = {'OrderID':2000,'CustomerID':3000}
df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
df
# Out:
#        OrderID CustomerID   CustomerName    Age  Gender      City State  \
# 0     ORD00001   CUST0103     John Smith   22.0  Female   Chicago    PA
# 1     ORD00002   CUST0271  William Moore   18.0    Male   Chicago    OH
# 2     ORD00003   CUST0107  William Moore  120.0  Female  San Jose    AZ
# 3     ORD00004   CUST0072  Jessica White   29.0    Male    Dallas    NY
# 4     ORD00005   CUST0189  Lisa Anderson   53.0  Female   Houston    NY
# ...        ...        ...            ...    ...     ...       ...   ...
# 1012  ORD00132   CUST0045   Tom Martinez   23.0  Female  New York    NY
# 1013  ORD00026   CUST0188   Chris Wilson   29.0    Male  New York    PA
# 1014  ORD00828   CUST0178   James Harris   46.0    Male  New York    CA
# 1015      2000       3000            NaN    NaN     NaN       NaN   NaN
# 1016      2000       3000            NaN    NaN     NaN       NaN   NaN
#
#            Category ProductName  Quantity  ...  Discount  ShippingCost  \
# ...
