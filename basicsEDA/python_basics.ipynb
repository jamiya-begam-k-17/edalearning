# %%
#Dictionary
dict = {"nameKey":"Jamii","ageKey":18}
dict
# Out:
# {'nameKey': 'Jamii', 'ageKey': 18}

# %%
dict["ageKey"]=19 #Update

# %%
dict["ageKey"] #Access by key
# Out:
# 19

# %%
dict["gender"]="female" #Add key value
dict
# Out:
# {'nameKey': 'Jamii', 'ageKey': 19, 'gender': 'female'}

# %%
#Sets
sets = {"Java","Python","Java"}
sets
# Out:
# {'Java', 'Python'}

# %%
sets.add("C++")  #Add value
sets
# Out:
# {'C++', 'Python'}

# %%
sets.remove("Java") #Remove value
sets
# Out:
# {'C++', 'Python'}

# %%
#Tuple
tuple = (1.7,1.8) #It is immutable
tuple
# Out:
# (1.7, 1.8)

# %%
#List
li = [1,2,3]

# %%
li.append(4) #Append a value to list

# %%
li.remove(3) #Remove value from the list

# %%
li[2] #Access value by index
# Out:
# 4

# %%
len(li)
# Out:
# 3

# %%
#Conditional Statements
x = int(input("Enter your age"))
if x >= 18 and x < 50:
    print("You are an Adult.")
elif x >= 50:
    print("You are seniour citizen")
else:
    print("You are a kid")
# Out:
# You are seniour citizen

# %%
name = input("Enter your name")
