# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # for data visualization
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\jamiy\Downloads\6fef6710-5c0d-4e1c-8b0a-576cfa2a84b4oKToW\DA314_S4_OrderDetails_Data_Concept.csv")

# %%
p_chart=df['payment_method'].value_counts()
plt.figure(figsize=(8,4))
plt.pie(p_chart,labels=p_chart.index,autopct="%1.1f%%",startangle=90)
plt.title("Payment Method Share")
plt.show()

# %%
sns.violinplot(
    x = "city_restaurant",
    y = "delivery_time_min",
    data = df,
    color = "#Fa8863"
)
plt.xticks(rotation=45)
plt.show()
